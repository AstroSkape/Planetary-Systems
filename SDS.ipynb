# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Planetary_Systems.csv")

# %%
data_top = data.head()
data_top
# Out:
#     pl_name hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0  11 Com b   11 Com        2        1  Radial Velocity       2007
# 1  11 Com b   11 Com        2        1  Radial Velocity       2007
# 2  11 UMi b   11 UMi        1        1  Radial Velocity       2009
# 3  11 UMi b   11 UMi        1        1  Radial Velocity       2009
# 4  11 UMi b   11 UMi        1        1  Radial Velocity       2009
#
#                             disc_facility              soltype  \
# 0                        Xinglong Station  Published Confirmed
# 1                        Xinglong Station  Published Confirmed
# 2  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 3  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  pl_orbper  ...  sy_vmagerr2  sy_kmag  sy_kmagerr1  \
# 0                0  326.03000  ...       -0.023    2.282        0.346
# ...

# %%
data.isnull().sum()
# Out:
# pl_name              0
# hostname             0
# sy_snum              0
# sy_pnum              0
# discoverymethod      0
#                   ...
# sy_gaiamagerr1     487
# sy_gaiamagerr2     487
# rowupdate            0
# pl_pubdate           1
# releasedate          0
# Length: 87, dtype: int64

# %%
data.isnull().sum()
# Out:
# pl_name              0
# hostname             0
# sy_snum              0
# sy_pnum              0
# discoverymethod      0
#                   ...
# sy_gaiamagerr1     487
# sy_gaiamagerr2     487
# rowupdate            0
# pl_pubdate           1
# releasedate          0
# Length: 87, dtype: int64

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is DAEA-B97D
#
#  Directory of D:\Programs\CSE_Year2\SDS
#
# 21-Sep-20  10:23 PM    <DIR>          .
# 21-Sep-20  10:23 PM    <DIR>          ..
# 21-Sep-20  10:09 PM    <DIR>          .ipynb_checkpoints
# 21-Sep-20  07:28 PM        11,458,923 Planetary_Systems.csv
# 21-Sep-20  10:23 PM            33,945 SDS.ipynb
# 21-Sep-20  10:09 PM            78,388 SDS_1.ipynb
# 21-Sep-20  10:07 PM                72 Untitled.ipynb
#                4 File(s)     11,571,328 bytes
#                3 Dir(s)  267,096,477,696 bytes free

# %%
missing_values=['n/a','na','','NaN',' ']
data = pd.read_csv('Planetary_Systems.csv', na_values = missing_values)
                   
(data.isnull().sum().sum())/(26789*87)
# Out:
# 0.3075486035398815

# %%
data
# Out:
#          pl_name hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0       11 Com b   11 Com        2        1  Radial Velocity       2007
# 1       11 Com b   11 Com        2        1  Radial Velocity       2007
# 2       11 UMi b   11 UMi        1        1  Radial Velocity       2009
# 3       11 UMi b   11 UMi        1        1  Radial Velocity       2009
# 4       11 UMi b   11 UMi        1        1  Radial Velocity       2009
# ...          ...      ...      ...      ...              ...        ...
# 26784  ups And d  ups And        2        3  Radial Velocity       1999
# 26785  ups And d  ups And        2        3  Radial Velocity       1999
# 26786  ups And d  ups And        2        3  Radial Velocity       1999
# 26787   xi Aql b   xi Aql        1        1  Radial Velocity       2007
# 26788   xi Aql b   xi Aql        1        1  Radial Velocity       2007
#
#                                 disc_facility              soltype  \
# ...

# %%
716786/(26789*87)
# Out:
# 0.3075486035398815
